# %%
from ipywidgets import Video, Image
from IPython.display import display
import pandas as pd
import numpy as np
import cv2
import base64

# %%
from IPython.display import Video
Video('./demo/desired_inference_visualisation.mp4', embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
pd.read_csv("./demo/demo_gaze_results.csv")
# Out:
#       frame   pupil2D_x   pupil2D_y     gaze_x     gaze_y  confidence  \
# 0         9  189.107745  126.349404  73.850949  94.033419    0.982884
# 1        10  189.113400  126.345826  73.850121  94.033040    0.982840
# 2        11  189.107745  126.349404  73.850949  94.033419    0.982885
# 3        12         NaN         NaN        NaN        NaN         NaN
# 4        13         NaN         NaN        NaN        NaN         NaN
# 5        14         NaN         NaN        NaN        NaN         NaN
# 6        15         NaN         NaN        NaN        NaN         NaN
# 7        16         NaN         NaN        NaN        NaN         NaN
# 8        17         NaN         NaN        NaN        NaN         NaN
# 9        18         NaN         NaN        NaN        NaN         NaN
# 10       19         NaN         NaN        NaN        NaN         NaN
# 11       20         NaN         NaN        NaN        NaN         NaN
# ...
